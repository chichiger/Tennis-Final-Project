# %%
#########################################################################################################
#set up libraries
import requests
from bs4 import BeautifulSoup
import csv
import re
import datetime
from pandas import DataFrame as df
from time import sleep
import time
import sys
reload(sys)
sys.setdefaultencoding('utf8')
##########################################################################################################
#get soup of each hote;
#set up lists
players = []
tlst = []
weight = []
height = []
name = []
age = []
rank = []
wlratio = []
turpro = []
bday = []
court = []
ctype = []
ct = []
tp = []
country = []
playstyle = []
coach = []
#basic setup to get hotel info
bs_url = 'http://www.atpworldtour.com/en/scores/results-archive'
cty_url = bs_url
response = requests.get(cty_url)
html = response.text.encode('utf-8')
# create a beautifulsoup object of the search page of boston hotel
atp_soup = BeautifulSoup(html, "lxml")
#print(cty_url)
#############################################################################################
#getting court type
for i in range (0,201):#201
    details = atp_soup.find_all('div', class_ = 'item-details')[i].find(text=True)
    details = ' '.join(details.split())
    #print(details)
    court.append(details)
    
    value = atp_soup.find_all('div', class_ = 'item-details')[i].find('span', class_ = 'item-value').find(text=True)
    value = ' '.join(value.split())
    ctype.append(value)
        
court = court[1::3]
ctype = ctype[1::3]
#########################################################################################################
for i in range (0,67):
    tennis_boxes = atp_soup.find_all('a',class_='button-border')[i]['href']
    tlst.append(tennis_boxes)
#############################################################################################
#looping through to get each link
for x in range (0,67):#67
    bs_url = 'http://www.atpworldtour.com'+ tlst[x]
    print(bs_url)
    res = requests.get(bs_url)
    html = res.text.encode('utf-8')
    # create a beautifulsoup object of the search page of boston hotel
    tennis_soup = BeautifulSoup(html, "lxml")
#############################################################################################
    #length of loop calc
    lenply = len(tennis_soup.find_all('td', class_='day-table-name'))
    #player links
    #player name
    for w in range (0,lenply):    
        name.append(tennis_soup.find_all('td', class_='day-table-name')[w].text.strip('\t\r\n'))
    ########################
    for w in range (0,lenply):    
        players_boxes = tennis_soup.find_all('td', class_='day-table-name')[w].find('a',class_ = "")['href']
        players.append(players_boxes)
    ############################################
    for z in range (0, lenply):
        bs2_url = 'http://www.atpworldtour.com'+ players[z]
        #print(bs2_url)
        res2 = requests.get(bs2_url)
        html2 = res2.text.encode('utf-8')
        # create a beautifulsoup object of the search page of boston hotel
        player_soup = BeautifulSoup(html2, "lxml")
        ##############################################################
        #attributes
        for y in  range (0,1):
            ##############################################################
            try:
                bday.append(player_soup.find('span', class_='table-birthday').text.strip('\t\r\n'))
            except:
                bday.append("N/A")
            ##############################################################    
            try:    
                weight.append(player_soup.find('span', class_='table-weight-lbs').text.strip('\t\r\n'))
            except:
                weight.append("N/A")
            ##############################################################    
            try:    
                height.append(player_soup.find('span', class_='table-height-cm-wrapper').text.strip('\t\r\n'))
            except:
                height.append("N/A")
            ##############################################################                   
            try:
                rank.append(player_soup.find('div', class_='data-number').text.strip('\t\r\n'))
            except:
                rank.append("N/A")
            ##############################################################                  
            try:
                age.append(player_soup.find('div', class_='player-profile-hero-table').find('div',class_ = 'table-big-value').text.strip('\t\r\n')[0:2])
            except:
                age.append("N/A")
            ##############################################################
            try:
                turpro.append(player_soup.find_all('div', class_='player-profile-hero-table')[y].find_all('div',class_ = 'table-big-value')[1].text.strip('\t\r\n'))
            except:
                turpro.append("N/A")
            ##############################################################
            try:
                playstyle.append(player_soup.find_all('div', class_='table-value')[2].text.strip('\t\r\n'))
            except:
                playstyle.append("N/A")
            ##############################################################
            try:
                country.append(player_soup.find('div', class_='table-value').text.strip('\t\r\n'))
            except:
                country.append("N/A")
            ##############################################################
            try:
                coach.append(player_soup.find_all('div', class_='table-value')[3].text.strip('\t\r\n'))
            except:
                coach.append("N/A")
            ##############################################################            
            try:
                wlratio.append(player_soup.find_all('div', class_='stat-value')[6].text.strip('\t\r\n'))
            except:
                wlratio.append("N/A")              
            ##############################################################    
##############################################################################################
tot = [name,age,bday,weight,height,rank,turpro,country,playstyle,coach,wlratio]
tennistable2 = df(tot).transpose()
tennistable2.columns = ['Name','Age','Birthday','Weight','Height','Rank','Turned Pro','Country','Playstyle','Coach','Wins:Loss']
##############################################################################################

# %%
tennistable2 #just for aus open to test
# Out:
#                          Name Age      Birthday Weight   Height Rank  \
# 0               Roger Federer  36  (1981.08.08)    187  (185cm)    2
# 1                Rafael Nadal  31  (1986.06.03)    188  (185cm)    1
# 2               Roger Federer  36  (1981.08.08)    187  (185cm)    2
# 3               Stan Wawrinka  32  (1985.03.28)    179  (183cm)    7
# 4                Rafael Nadal  31  (1986.06.03)    188  (185cm)    1
# 5             Grigor Dimitrov  26  (1991.05.16)    176  (191cm)    6
# 6                Rafael Nadal  31  (1986.06.03)    188  (185cm)    1
# 7                Milos Raonic  26  (1990.12.27)    216  (196cm)   24
# 8               Stan Wawrinka  32  (1985.03.28)    179  (183cm)    7
# 9          Jo-Wilfried Tsonga  32  (1985.04.17)    200  (188cm)   15
# 10            Grigor Dimitrov  26  (1991.05.16)    176  (191cm)    6
# 11               David Goffin  26  (1990.12.07)    150  (180cm)    8
# 12              Roger Federer  36  (1981.08.08)    187  (185cm)    2
# 13              Mischa Zverev  30  (1987.08.22)    194  (191cm)   33
# 14              Mischa Zverev  30  (1987.08.22)    194  (191cm)   33
# 15                Andy Murray  30  (1987.05.15)    185  (191cm)   16
# 16               Milos Raonic  26  (1990.12.27)    216  (196cm)   24
# 17      Roberto Bautista Agut  29  (1988.04.14)    168  (183cm)   20
# 18              Stan Wawrinka  32  (1985.03.28)    179  (183cm)    7
# 19              Andreas Seppi  33  (1984.02.21)    165  (191cm)   89
# 20              Roger Federer  36  (1981.08.08)    187  (185cm)    2
# 21              Kei Nishikori  27  (1989.12.29)    165  (178cm)   22
# 22               Rafael Nadal  31  (1986.06.03)    188  (185cm)    1
# 23               Gael Monfils  31  (1986.09.01)    177  (193cm)   46
# 24               David Goffin  26  (1990.12.07)    150  (180cm)    8
# 25              Dominic Thiem  24  (1993.09.03)    180  (185cm)    4
# 26         Jo-Wilfried Tsonga  32  (1985.04.17)    200  (188cm)   15
# 27               Daniel Evans  27  (1990.05.23)    165  (175cm)  134
# 28            Grigor Dimitrov  26  (1991.05.16)    176  (191cm)    6
# 29              Denis Istomin  31  (1986.09.07)    194  (188cm)   56
# ..                        ...  ..           ...    ...      ...  ...
# 448  Adrian Menendez-Maceiras  32  (1985.10.28)    163  (183cm)  127
# 449             Daniel Brands  30  (1987.07.17)    203  (196cm)  312
# 450             Hiroki Moriya  27  (1990.10.16)    143  (170cm)  341
# 451           Harry Bourchier  21  (1996.01.24)    167  (185cm)  422
# 452                Blake Mott  21  (1996.04.21)    170  (180cm)  277
# 453     Alexander Kudryavtsev  32  (1985.10.26)    174  (183cm)  538
# 454           Bradley Mousley  21  (1996.01.03)    181  (188cm)   99
# 455          Marton Fucsovics  25  (1992.02.08)    181  (188cm)   84
# 456             Reilly Opelka  20  (1997.08.28)    220  (211cm)  220
# 457        Stefano Napolitano  22  (1995.04.11)    198  (196cm)  212
# 458             Yannik Reuter  26  (1991.03.06)    N/A      N/A  438
# 459               Steven Diez  26  (1991.03.17)    N/A      N/A  298
# 460                Noah Rubin  21  (1996.02.21)    150  (175cm)  203
# 461       Cedrik-Marcel Stebe  27  (1990.10.09)    154  (183cm)   81
# 462             Andrey Rublev  20  (1997.10.20)    150  (188cm)   39
# 463               Max Purcell  19  (1998.04.03)    165  (185cm)  276
# 464            Mohamed Safwat  27  (1990.09.19)    183  (183cm)  217
# 465               Pedro Sousa  29  (1988.05.27)    154  (178cm)  125
# 466           Akira Santillan  20  (1997.05.22)    170  (180cm)  144
# 467                Elias Ymer  21  (1996.04.10)    173  (183cm)  146
# 468        John-Patrick Smith  28  (1989.01.24)    185  (188cm)  216
# 469           Agustin Velotti  25  (1992.05.24)    N/A      N/A  480
# 470        Stefanos Tsitsipas  19  (1998.08.12)    183  (193cm)   87
# 471       Gavin Van Peperzeel  25  (1992.03.29)    163  (180cm)  357
# 472         Yasutaka Uchiyama  25  (1992.08.05)    172  (183cm)  128
# 473             Marko Tepavac  23  (1994.04.05)    198  (193cm)  430
# 474                Luca Vanni  32  (1985.06.04)    207  (198cm)  140
# 475             Federico Gaio  25  (1992.03.05)    185  (180cm)  251
# 476                     Di Wu  26  (1991.09.14)    143  (175cm)  191
# 477            Maverick Banes  25  (1992.04.10)    N/A      N/A  275
#
#     Turned Pro                       Country  \
# 0         1998            Basel, Switzerland
# 1         2001      Manacor, Mallorca, Spain
# 2         1998            Basel, Switzerland
# 3         2002         Lausanne, Switzerland
# 4         2001      Manacor, Mallorca, Spain
# 5         2008             Haskovo, Bulgaria
# 6         2001      Manacor, Mallorca, Spain
# 7         2008         Podgorica, Montenegro
# 8         2002         Lausanne, Switzerland
# 9         2004               Le Mans, France
# 10        2008             Haskovo, Bulgaria
# 11        2009              Rocourt, Belgium
# 12        1998            Basel, Switzerland
# 13        2005                Moscow, Russia
# 14        2005                Moscow, Russia
# 15        2005             Glasgow, Scotland
# 16        2008         Podgorica, Montenegro
# 17        2005  Castellon de la Plana, Spain
# 18        2002         Lausanne, Switzerland
# 19        2002                Bolzano, Italy
# 20        1998            Basel, Switzerland
# 21        2007                Shimane, Japan
# 22        2001      Manacor, Mallorca, Spain
# 23        2004                 Paris, France
# 24        2009              Rocourt, Belgium
# 25        2011      Wiener Neustadt, Austria
# 26        2004               Le Mans, France
# 27        2006           Birmingham, England
# 28        2008             Haskovo, Bulgaria
# 29        2004              Orenburg, Russia
# ..         ...                           ...
# 448       2005               Marbella, Spain
# 449       2005           Deggendorf, Germany
# 450                             Tokyo, Japan
# 451                        Hobart, Australia
# 452                     Caringbah, Australia
# 453                    Yekaterinburg, Russia
# 454       2015      Modbury, South Australia
# 455       2010          Nyiregyhaza, Hungary
# 456       2015           St. Joseph, MI, USA
# 457       2013                 Biella, Italy
# 458
# 459
# 460       2015          Long Island, NY, USA
# 461       2010           Muehlacker, Germany
# 462       2014                Moscow, Russia
# 463                        Sydney, Australia
# 464                       El Mansoura, Egypt
# 465       2007              Lisbon, Portugal
# 466       2013                  Tokyo, Japan
# 467       2014                 Skara, Sweden
# 468       2012         Townsville, Australia
# 469
# 470       2016                Athens, Greece
# 471                                  Nambour
# 472       2011               Hokkaido, Japan
# 473                         Belgrade, Serbia
# 474                  Castel del Piano, Italy
# 475       2009                 Faenza, Italy
# 476       2009                  Wuhan, China
# 477
#
#                              Playstyle                              Coach  \
# 0    Right-Handed, One-Handed Backhand    Ivan Ljubicic and Severin Lüthi
# 1     Left-Handed, Two-Handed Backhand         Carlos Moya and Toni Nadal
# 2    Right-Handed, One-Handed Backhand    Ivan Ljubicic and Severin Lüthi
# 3    Right-Handed, One-Handed Backhand
# 4     Left-Handed, Two-Handed Backhand         Carlos Moya and Toni Nadal
# 5    Right-Handed, One-Handed Backhand                   Daniel Vallverdu
# 6     Left-Handed, Two-Handed Backhand         Carlos Moya and Toni Nadal
# 7    Right-Handed, Two-Handed Backhand
# 8    Right-Handed, One-Handed Backhand
# 9    Right-Handed, Two-Handed Backhand                    Thierry Ascione
# 10   Right-Handed, One-Handed Backhand                   Daniel Vallverdu
# 11   Right-Handed, Two-Handed Backhand               Thierry Van Cleemput
# 12   Right-Handed, One-Handed Backhand    Ivan Ljubicic and Severin Lüthi
# 13    Left-Handed, Two-Handed Backhand               Alexander Zverev Sr.
# 14    Left-Handed, Two-Handed Backhand               Alexander Zverev Sr.
# 15   Right-Handed, Two-Handed Backhand       Ivan Lendl and Jamie Delgado
# 16   Right-Handed, Two-Handed Backhand
# 17   Right-Handed, Two-Handed Backhand  Tomas Carbonell and Pepe Vendrell
# 18   Right-Handed, One-Handed Backhand
# 19   Right-Handed, Two-Handed Backhand                    Massimo Sartori
# 20   Right-Handed, One-Handed Backhand    Ivan Ljubicic and Severin Lüthi
# 21   Right-Handed, Two-Handed Backhand    Dante Bottini and Michael Chang
# 22    Left-Handed, Two-Handed Backhand         Carlos Moya and Toni Nadal
# 23   Right-Handed, Two-Handed Backhand                   Mikael Tillstrom
# 24   Right-Handed, Two-Handed Backhand               Thierry Van Cleemput
# 25   Right-Handed, One-Handed Backhand                     Günter Bresnik
# 26   Right-Handed, Two-Handed Backhand                    Thierry Ascione
# 27   Right-Handed, One-Handed Backhand                        Mark Hilton
# 28   Right-Handed, One-Handed Backhand                   Daniel Vallverdu
# 29   Right-Handed, Two-Handed Backhand                  Klaudiya Istomina
# ..                                 ...                                ...
# 448  Right-Handed, Two-Handed Backhand               Manuel Martin Torres
# 449  Right-Handed, One-Handed Backhand
# 450  Right-Handed, Two-Handed Backhand                     Norihiro Maeda
# 451  Right-Handed, Two-Handed Backhand                         Simon Youl
# 452  Right-Handed, Two-Handed Backhand                       Peter Luczak
# 453                       Right-Handed
# 454  Right-Handed, One-Handed Backhand      Jack Reader and Craig Mousley
# 455  Right-Handed, Two-Handed Backhand                      Attila Savolt
# 456  Right-Handed, Two-Handed Backhand                      Dustin Taylor
# 457  Right-Handed, Two-Handed Backhand                    Cristian Brandi
# 458  Right-Handed, Two-Handed Backhand
# 459  Right-Handed, Two-Handed Backhand
# 460  Right-Handed, Two-Handed Backhand                    Stanford Boster
# 461   Left-Handed, Two-Handed Backhand                         Lars Uebel
# 462  Right-Handed, Two-Handed Backhand                   Fernando Vicente
# 463  Right-Handed, Two-Handed Backhand
# 464  Right-Handed, Two-Handed Backhand                   Gilbert Schaller
# 465  Right-Handed, Two-Handed Backhand                        Rui Machado
# 466  Right-Handed, One-Handed Backhand                    Ricardo Sanchez
# 467  Right-Handed, Two-Handed Backhand                    Robin Soderling
# 468   Left-Handed, Two-Handed Backhand                        Jacob Meyer
# 469                       Right-Handed
# 470  Right-Handed, One-Handed Backhand                Apostolos Tsitsipas
# 471  Right-Handed, Two-Handed Backhand      National Academy & Greg Smith
# 472  Right-Handed, Two-Handed Backhand                     Kentaro Masuda
# 473  Right-Handed, Two-Handed Backhand                       Nikola CIRIC
# 474  Right-Handed, Two-Handed Backhand                     Fabio Gorietti
# 475  Right-Handed, One-Handed Backhand                  Giancarlo Palumbo
# 476  Right-Handed, Two-Handed Backhand                 Davide Sanguinetti
# 477
#
#     Wins:Loss
# 0    1129-249
# 1     873-184
# 2    1129-249
# 3     465-262
# 4     873-184
# 5     252-161
# 6     873-184
# 7     288-132
# 8     465-262
# 9     425-194
# 10    252-161
# 11    196-126
# 12   1129-249
# 13    110-155
# 14    110-155
# 15    655-184
# 16    288-132
# 17    212-130
# 18    465-262
# 19    327-350
# 20   1129-249
# 21    331-155
# 22    873-184
# 23    411-232
# 24    196-126
# 25    170-107
# 26    425-194
# 27      34-46
# 28    252-161
# 29    211-227
# ..        ...
# 448      3-11
# 449     59-91
# 450       2-9
# 451       0-0
# 452       0-1
# 453      5-15
# 454       3-2
# 455     22-20
# 456      6-13
# 457       1-2
# 458       0-0
# 459       1-6
# 460       3-9
# 461     21-30
# 462     33-37
# 463       0-1
# 464      4-14
# 465       9-8
# 466       2-7
# 467     13-30
# 468      5-15
# 469       0-1
# 470      4-10
# 471       0-0
# 472      7-12
# 473       0-1
# 474      5-16
# 475       2-4
# 476       2-9
# 477       0-0
#
# [478 rows x 11 columns]
